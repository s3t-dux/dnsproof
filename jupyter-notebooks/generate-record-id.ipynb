# %%
import hashlib
import json

def generate_record_id(record: dict) -> str:
    """Generate a stable ID for a DNS record based on its type/name/value/priority/ttl."""
    content = json.dumps({
        "type": record["type"],
        "name": record["name"],
        "value": record["value"],
        "priority": record.get("priority"),
        "port": record.get("port"),
        "target": record.get("target"),
        "ttl": record.get("ttl", 3600),
    }, sort_keys=True)
    return hashlib.sha256(content.encode()).hexdigest()

# %%
record_id = generate_record_id({"type": "TXT", "name":"@", "value": "test-edited","ttl": 3600})
print(record_id)
# Out:
# 3ea200f692b42835a2492f36e6df9958f010825d3732ab642f5236da41e19354
